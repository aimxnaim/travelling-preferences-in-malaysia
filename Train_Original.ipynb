# %%
# Mission All = default 
 
# Read data from external file 
import pandas as pd 
dfCSV = pd.read_csv("train-IT.csv") 
 
# Data slicing 
x = dfCSV.iloc[:, 0:15]  #features
y = dfCSV.iloc[:, [15]]  #label 
x.head() 
 
# Convert dataframe to array 
import numpy as np

x = x.values 
y = y.values 
y = y.ravel() 
 
# K-Nearest Neighbor 
from sklearn.neighbors import KNeighborsClassifier 

# Create a k-NN classifier with custom weights
modelKnn = KNeighborsClassifier() 
modelKnn.fit(x, y) 

yPred = modelKnn.predict(x) 

# Testing & performance analysis -Trainning data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y, yPred), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Training: Accuracy Score: {0}'.format(skm.accuracy_score(y, yPred)) 
plt.title(all_sample_title, size = 15);



# Read data from external file 
import pandas as pd 
dfCSV2 = pd.read_csv("test-IT.csv") 
 
#Data slicing 
x2 = dfCSV2.iloc[:, 0:15]  #features
y2 = dfCSV2.iloc[:, [15]]  #label
x2.head() 
 
# Convert dataframe to array 
x2 = x2.values 
y2 = y2.values 
y2 = y2.ravel() 
 
yPred2 = modelKnn.predict(x2)  
 
# Testing & performance analysis -Testing data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y2, yPred2), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Testing: Accuracy Score: {0}'.format(skm.accuracy_score(y2, yPred2)) 
plt.title(all_sample_title, size = 15);

# %%
dfCSV.head()
# Out:
#    AGE  GENDER  OCCUPATION:  INCOME (RM XXXX):  MARITAL STATUS  \
# 0   23       1            1               3400               0
# 1   30       0            1                  0               0
# 2    5       1            0               2000               1
# 3   27       1            1               3290               1
# 4   11       1            1               3500               1
#
#    What is your travelling duration?  Why you usually travel?  \
# 0                                  0                        1
# 1                                  1                        1
# 2                                  1                        1
# 3                                  2                        3
# 4                                  0                        0
#
#    What is your budget for travelling?  How long do you plan for your travel?  \
# 0                                    5                                      3
# 1                                    3                                      1
# 2                                    1                                      3
# 3                                    1                                      0
# 4                                    1                                      1
#
#    Usually where do you plan to stay?  Travelling frequency  \
# 0                                   1                     1
# 1                                   4                     0
# 2                                   3                     0
# 3                                   4                     2
# 4                                   0                     0
#
#    Travelling Transportation  Do you prefer using tour guide?  \
# 0                          2                                0
# 1                          3                                1
# 2                          3                                0
# 3                          1                                1
# 4                          3                                0
#
#    Do you prefer travelling local or overseas?  Language preferences  \
# 0                                            0                     0
# 1                                            1                     1
# 2                                            1                     1
# 3                                            1                     1
# 4                                            1                     1
#
#    Do you prefer solo or group travel?
# 0                                    0
# 1                                    0
# 2                                    1
# 3                                    1
# 4                                    0

# %%
# Let's predict!

newData = [[21,1,1,0000,0,1,1,0,2,3,1,1,0,2,1]]

predictionResult = modelKnn.predict(newData)

if(predictionResult == 1):
    print("Prediction result = Group")
else:
    print("Prediction result = Solo")
# Out:
# Prediction result = Solo

# %%
# Mission All = default 
 
# Read data from external file 
import pandas as pd 
dfCSV = pd.read_csv("k-fold2-train.csv") 
 
# Data slicing 
x = dfCSV.iloc[:, 0:15]  #features
y = dfCSV.iloc[:, [15]]  #label 
x.head() 
 
# Convert dataframe to array 
import numpy as np

x = x.values 
y = y.values 
y = y.ravel() 
 
# K-Nearest Neighbor 
from sklearn.neighbors import KNeighborsClassifier 
# Define custom weight function
def custom_weight(distances):
    weights = np.exp(-distances)
    return weights

# Create a k-NN classifier with custom weights
modelKnn = KNeighborsClassifier(p=3, weights=custom_weight, n_neighbors=10) 
modelKnn.fit(x, y) 

yPred = modelKnn.predict(x) 

# Testing & performance analysis -Trainning data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y, yPred), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Trainning: Accuracy Score: {0}'.format(skm.accuracy_score(y, yPred)) 
plt.title(all_sample_title, size = 15);


# Read data from external file 
import pandas as pd 
dfCSV2 = pd.read_csv("k-fold2-test.csv") 
 
#Data slicing 
x2 = dfCSV2.iloc[:, 0:15]  #features
y2 = dfCSV2.iloc[:, [15]]  #label
x2.head() 
 
# Convert dataframe to array 
x2 = x2.values 
y2 = y2.values 
y2 = y2.ravel() 
 

# K-Nearest Neighbor 
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier 
# Define custom weight function
def custom_weight(distances):
    weights = np.exp(-distances)
    return weights

# Define custom weight function
def custom_weight(distances):
    weights = np.exp(-distances)
    return weights

# Create a k-NN classifier with custom weights
modelKnn = KNeighborsClassifier( n_neighbors=10) 
modelKnn.fit(x2, y2) 

yPred2 = modelKnn.predict(x2)  
 
# Testing & performance analysis -Testing data 
import sklearn.metrics as skm 
import matplotlib.pyplot as plt 
import seaborn as sns 
plt.figure(figsize=(9,9)) 
sns.heatmap(skm.confusion_matrix(y2, yPred2), annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r'); 
plt.ylabel('Actual label'); 
plt.xlabel('Predicted label'); 
all_sample_title = 'Testing: Accuracy Score: {0}'.format(skm.accuracy_score(y2, yPred2)) 
plt.title(all_sample_title, size = 15);
